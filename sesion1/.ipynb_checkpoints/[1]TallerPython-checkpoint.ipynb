# %% [markdown]
# # SPS IEEE UNI - PYTHON
#
# *JEAN CARLOS VARGAS*

# %%
from IPython.display import Image
i = Image(filename = '../sesion1/data/logo1.jpg')

# %%
i

# %%
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
from IPython.display import Audio
Audio(url="http://www.nch.com.au/acm/8k16bitpcm.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="http://www.nch.com.au/acm/8k16bitpcm.wav" type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# - [Herramientas de edición para Jupyter](Herramientas.ipynb)
#
#
# - [clase1]([2]clase1.ipynb)

# %% [markdown]
# ## Documentación
#
# - [Jupyter Notebook](http://jupyter-notebook.readthedocs.io/en/latest/notebook.html)

# %% [markdown]
# ## Tips para Jupyter
#
# - [Tips and tricks](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)
